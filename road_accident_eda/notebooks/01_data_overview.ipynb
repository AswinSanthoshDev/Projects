# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel("../data/raw/road_accident_data.xlsx")

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 6486
# Columns: 22

# %%
df.head()
# Out:
#       Accident_ID Accident_Date Accident_Time    Report_Timestamp    District  \
# 0  KER_ACC_100000    2023-04-25      00:47:00 2023-04-25 02:02:00   Kozhikode
# 1             NaN    2024-06-01      19:01:00 2024-06-01 21:29:00   Alappuzha
# 2  KER_ACC_100002    2025-04-05      05:44:00 2025-04-05 07:37:00      Kannur
# 3  KER_ACC_100003    2023-09-28      01:46:00 2023-09-28 03:48:00  Malappuram
# 4  KER_ACC_100004    2023-07-16      22:04:00 2023-07-16 22:20:00  Malappuram
#
#     Road_Type Weather_Condition Surface_Condition Light_Condition  \
# 0      Bridge             Clear               Dry          Night
# 1  Urban Road             Clear               NaN          Night
# 2  Rural Road             Clear               Wet          Night
# 3    Junction             Clear               Dry          Night
# 4     Highway               Fog               Dry          Night
#
#   Traffic_Density Vehicle_Type  Driver_Age Driver_Gender Alcohol_Involved  \
# 0          Medium        Truck        23.0          Male               No
# 1          Medium   Motorcycle        32.0           NaN               No
# 2             Low          Car        24.0        Female              Yes
# 3          Medium          Car        53.0        Female               No
# 4             NaN          Car        32.0        Female               No
#
#    Vehicle_Speed_kmph     Helmet_Used   Seatbelt_Used      Cause_Category  \
# 0                90.0  Not Applicable              No       Drunk Driving
# 1                58.0             Yes  Not Applicable  Mechanical Failure
# 2                54.0  Not Applicable             Yes  Mechanical Failure
# 3                32.0  Not Applicable             Yes                 NaN
# 4               112.0             NaN             Yes  Weather Conditions
#
#   Accident_Severity  Casualties_Count   Injury_Type  \
# 0             Minor               1.0     No Injury
# 1             Minor               1.0     No Injury
# 2           Serious               1.0  Minor Injury
# 3             Minor               2.0  Minor Injury
# 4           Serious               2.0  Major Injury
#
#    Emergency_Response_Time_Min
# 0                          6.0
# 1                         13.0
# 2                         13.0
# 3                         25.0
# 4                         22.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6486 entries, 0 to 6485
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Accident_ID                  6204 non-null   str
#  1   Accident_Date                6486 non-null   datetime64[us]
#  2   Accident_Time                6486 non-null   str
#  3   Report_Timestamp             6486 non-null   datetime64[us]
#  4   District                     6185 non-null   str
#  5   Road_Type                    6187 non-null   str
#  6   Weather_Condition            6220 non-null   str
#  7   Surface_Condition            6193 non-null   str
#  8   Light_Condition              6182 non-null   str
#  9   Traffic_Density              6208 non-null   str
#  10  Vehicle_Type                 6208 non-null   str
#  11  Driver_Age                   6208 non-null   float64
#  12  Driver_Gender                6200 non-null   str
#  13  Alcohol_Involved             6203 non-null   str
#  14  Vehicle_Speed_kmph           6185 non-null   float64
#  15  Helmet_Used                  6172 non-null   str
#  16  Seatbelt_Used                6223 non-null   str
#  17  Cause_Category               6156 non-null   str
#  18  Accident_Severity            6184 non-null   str
#  19  Casualties_Count             6177 non-null   float64
#  20  Injury_Type                  6203 non-null   str
#  21  Emergency_Response_Time_Min  6179 non-null   float64
# dtypes: datetime64[us](2), float64(4), str(16)
# memory usage: 1.1 MB

# %%
df.describe()
# Out:
#                     Accident_Date            Report_Timestamp   Driver_Age  \
# count                        6486                        6486  6208.000000
# mean   2024-03-12 21:05:56.336725  2024-03-13 10:39:24.098057    44.551385
# min           2023-01-01 00:00:00         2023-01-01 07:01:00    18.000000
# 25%           2023-07-31 00:00:00         2023-07-31 20:16:00    31.000000
# 50%           2024-03-14 00:00:00         2024-03-14 13:57:00    44.000000
# 75%           2024-10-20 18:00:00         2024-10-21 01:20:45    58.000000
# max           2025-05-30 00:00:00         2025-05-31 02:07:00   420.000000
# std                           NaN                         NaN    18.964967
#
#        Vehicle_Speed_kmph  Casualties_Count  Emergency_Response_Time_Min
# count         6185.000000       6177.000000                  6179.000000
# mean            72.577526          1.881982                    20.075417
# min             20.000000          0.000000                     5.000000
# 25%             55.000000          1.000000                    12.000000
# 50%             70.000000          2.000000                    19.000000
# 75%             88.000000          2.000000                    25.000000
# max            665.000000        253.000000                   222.000000
# std             30.512598          5.756290                    10.456874

# %%
df.nunique().sort_values()
# Out:
# Driver_Gender                     2
# Alcohol_Involved                  2
# Surface_Condition                 3
# Light_Condition                   3
# Traffic_Density                   3
# Helmet_Used                       3
# Accident_Severity                 3
# Seatbelt_Used                     3
# Weather_Condition                 4
# Injury_Type                       4
# Vehicle_Type                      5
# Road_Type                         5
# Cause_Category                    5
# District                         14
# Casualties_Count                 17
# Emergency_Response_Time_Min      62
# Driver_Age                       68
# Vehicle_Speed_kmph              144
# Accident_Date                   880
# Accident_Time                  1425
# Accident_ID                    6155
# Report_Timestamp               6421
# dtype: int64

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

categorical_cols = df.select_dtypes(include=['object', 'string']).columns

datetime_cols = df.select_dtypes(include=['datetime']).columns

print("Numerical:")
print(numerical_cols)

print("\nCategorical:")
print(categorical_cols)

print("\ndatetime:")
print(datetime_cols)
# Out:
# Numerical:
# Index(['Driver_Age', 'Vehicle_Speed_kmph', 'Casualties_Count',
#        'Emergency_Response_Time_Min'],
#       dtype='str')
#
# Categorical:
# Index(['Accident_ID', 'Accident_Time', 'District', 'Road_Type',
#        'Weather_Condition', 'Surface_Condition', 'Light_Condition',
#        'Traffic_Density', 'Vehicle_Type', 'Driver_Gender', 'Alcohol_Involved',
#        'Helmet_Used', 'Seatbelt_Used', 'Cause_Category', 'Accident_Severity',
#        'Injury_Type'],
#       dtype='str')
#
# datetime:
# Index(['Accident_Date', 'Report_Timestamp'], dtype='str')

# %%
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_percentage
})

missing_df.sort_values(by='Percentage', ascending=False)
# Out:
#                              Missing Values  Percentage
# Cause_Category                          330    5.087882
# Helmet_Used                             314    4.841196
# Casualties_Count                        309    4.764107
# Emergency_Response_Time_Min             307    4.733272
# Light_Condition                         304    4.687018
# Accident_Severity                       302    4.656183
# Vehicle_Speed_kmph                      301    4.640765
# District                                301    4.640765
# Road_Type                               299    4.609929
# Surface_Condition                       293    4.517422
# Driver_Gender                           286    4.409497
# Alcohol_Involved                        283    4.363244
# Injury_Type                             283    4.363244
# Accident_ID                             282    4.347826
# Traffic_Density                         278    4.286155
# Vehicle_Type                            278    4.286155
# Driver_Age                              278    4.286155
# Weather_Condition                       266    4.101141
# Seatbelt_Used                           263    4.054887
# Accident_Time                             0    0.000000
# Accident_Date                             0    0.000000
# Report_Timestamp                          0    0.000000

# %%
total_cells = df.shape[0] * df.shape[1]
missing_cells = df.isnull().sum().sum()

missing_percentage = (missing_cells / total_cells) * 100

print(f"Total Missing Values: {missing_cells}")
print(f"Missing Percentage: {missing_percentage:.2f}%")
# Out:
# Total Missing Values: 5557
# Missing Percentage: 3.89%

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 50

# %% [markdown]
# Data Quality Issue Log
#
# Issue           Observation
#
# Missing Values	~4%
# Duplicate Rows	50
# Outliers	    Expected in numerical columns
# Date Columns	Need datatype conversion
# Categorical     Standardization	To be checked

# %% [markdown]
# Business Questions
#
# 1. Which district has the most accidents?
# 2. Does weather influence accident severity?
# 3. Are night-time accidents more severe?
# 4. Does overspeeding increase casualties?
# 5. Which vehicle types are most accident-prone?
# 6. Do helmets and seatbelts reduce severity?
# 7. Do drunk-driving accidents cause more fatalities?
